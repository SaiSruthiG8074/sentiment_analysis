# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 5.0MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2021.5.30)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs=SentimentIntensityAnalyzer()

# %%
text='The product is really good'
vs.polarity_scores(text)
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.556, 'pos': 0.444}

# %%
text2='Who all loves older size i.e., 4.7 inch should definitely go for this.Nothing is better than XR,XS or 11.Best for price and usage'
vs.polarity_scores(text)
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.556, 'pos': 0.444}

# %%
text3='Everything is fine of the mobile except battery'
vs.polarity_scores(text)
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.556, 'pos': 0.444}

# %%
#web scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
url='https://www.inshorts.com/en/read/sports'
news_data=[]
new_category=url.split('/')[-1]
data=requests.get(url)
soup=BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Mix panel script start -->
# <script>
#   (function(f,b){if(!b.__SV){var e,g,i,h;window.mixpanel=b;b._i=[];b.init=function(e,f,c){function g(a,d){var b=d.split(".");2==b.length&&(a=a[b[0]],d=b[1]);a[d]=function(){a.push([d].concat(Array.prototype.slice.call(arguments,0)))}}var a=b;"undefined"!==typeof c?a=b[c]=[]:c="mixpanel";a.people=a.people||[];a.toString=function(a){var d="mixpanel";"mixpanel"!==c&&(d+="."+c);a||(d+=" (stub)");return d};a.people.toString=function(){return a.toString(1)+".people (stub)"};i="disable time_event track track_pageview track_links track_forms track_with_groups add_group set_group remove_group register register_once alias unregister identify name_tag set_config reset opt_in_tracking opt_out_tracking has_opted_in_tracking has_opted_out_tracking clear_opt_in_out_tracking start_batch_senders people.set people.set_once people.unset people.increment people.append people.union people.track_charge people.clear_charges people.delete_user people.remove".split(" ");
#   for(h=0;h<i.length;h++)g(a,i[h]);var j="set set_once union unset remove delete".split(" ");a.get_group=function(){function b(c){d[c]=function(){call2_args=arguments;call2=[c].concat(Array.prototype.slice.call(call2_args,0));a.push([e,call2])}}for(var d={},e=["get_group"].concat(Array.prototype.slice.call(arguments,0)),c=0;c<j.length;c++)b(j[c]);return d};b._i.push([e,f,c])};b.__SV=1.2;e=f.createElement("script");e.type="text/javascript";e.async=!0;e.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?
#   MIXPANEL_CUSTOM_LIB_URL:"file:"===f.location.protocol&&"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";g=f.getElementsByTagName("script")[0];g.parentNode.insertBefore(e,g)}})(document,window.mixpanel||[]);
#   mixpanel.init("a99a1037068944b00a0cc8ee56c94e8c")
#   mixpanel.track("pageview")
#   </script>
# <!-- Mix panel script end -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <!-- Add After importing GA and Mixpanel scripts -->
# <script>
#   function track_GA_Mixpanel({hitType, category, action, label, value = 1}){
#     if (window && window.ga) {
#       ga('send', {
#             hitType: 'event',
#             eventCategory: category,
#             eventAction: action,
#             eventLabel: label,
#             eventValue: value
#         });
#     }
#     // mix panel analytics
#     if(window && window.mixpanel){
#         mixpanel.track("event", {category, action, label, value});
#     }
#   }
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToAllNews', 'action': 'clicked', 'label': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToIndiaNews', 'action': 'clicked', 'label': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToBusinessNews', 'action': 'clicked', 'label':  'RedirectedToBusinessNews' });"> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTosportsNews', 'action': 'clicked', 'label': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked', 'label': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked',   'label': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTotechnologyNews', 'action': 'clicked', 'label': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTostartupNews', 'action': 'clicked', 'label': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToEntertainmentNews', 'action': 'clicked', 'label': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToMiscellaneousNews', 'action': 'clicked', 'label': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTohatkeNews', 'action': 'clicked', 'label': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToscienceNews', 'action': 'clicked', 'label': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToautomobileNews', 'action': 'clicked', 'label': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ill-never-apologise-for-who-i-am-rashford-on-being-racially-abused-after-euro-final-1626168858574" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="I'll never apologise for who I am: Rashford on being racially abused after Euro final" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626168026787_701.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626168026787_701.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ill-never-apologise-for-who-i-am-rashford-on-being-racially-abused-after-euro-final-1626168858574" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'I'll%20never%20apologise%20for%20who%20I%20am%3A%20Rashford%20on%20being%20racially%20abused%20after%20Euro%20final)' });" style="color:#44444d!important">
# <span itemprop="headline">I'll never apologise for who I am: Rashford on being racially abused after Euro final</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/ill-never-apologise-for-who-i-am-rashford-on-being-racially-abused-after-euro-final-1626168858574"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T09:34:18.000Z" itemprop="datePublished">03:04 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">England forward Marcus Rashford took to Twitter to pen a note after being racially abused online for missing a penalty in the Euro 2020 final, which Italy won. He said he could take criticism for the missed penalty "all day long" but added, "I will never apologise for who I am and where I came from."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/ill-never-apologise-for-who-i-am-rashford-on-being-racially-abused-after-euro-final-1626168858574"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T09:34:18.000Z" itemprop="dateModified">03:04 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.hindustantimes.com/sports/football/marcus-rashford-sorry-for-missing-penalty-but-says-will-never-apologise-for-who-i-am-101626145677316-amp.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Hindustan%20Times' });" target="_blank">Hindustan Times</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/crawl-back-under-your-rock-uk-pm-to-those-racially-abusing-football-players-1626175121599" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Arshiya Chopra" itemprop="name"></span>
# </span>
# <span content="Crawl back under your rock: UK PM to those racially abusing football players" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626173078586_818.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626173078586_818.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/crawl-back-under-your-rock-uk-pm-to-those-racially-abusing-football-players-1626175121599" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Crawl%20back%20under%20your%20rock%3A%20UK%20PM%20to%20those%20racially%20abusing%20football%20players)' });" style="color:#44444d!important">
# <span itemprop="headline">Crawl back under your rock: UK PM to those racially abusing football players</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/crawl-back-under-your-rock-uk-pm-to-those-racially-abusing-football-players-1626175121599"><span class="short">short</span></a> by <span class="author">Arshiya Chopra</span> /
#       <span class="time" content="2021-07-13T11:18:41.000Z" itemprop="datePublished">04:48 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Condemning people who are racially abusing England players after the team's Euro 2020 final defeat against Italy, UK PM Boris Johnson said, "I hope you will crawl back under the rock from which you emerged." Black England players Bukayo Saka, Marcus Rashford and Jadon Sancho were racially abused after they failed to score in the penalty shootout in the final.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/crawl-back-under-your-rock-uk-pm-to-those-racially-abusing-football-players-1626175121599"><span class="short">short</span></a> by <span class="author">Arshiya Chopra</span> /
#       <span class="time" content="2021-07-13T11:18:41.000Z" itemprop="dateModified">04:48 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.wionews.com/world/i-hope-you-crawl-back-under-the-rock-uk-pm-johnson-condemns-racial-abuse-of-england-football-stars-397699?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'WION' });" target="_blank">WION</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/icc-dont-want-me-to-use-the-universe-boss-sticker-chris-gayle-1626179053620" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="ICC don't want me to use 'The Universe Boss' sticker: Chris Gayle" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626176676216_877.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626176676216_877.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/icc-dont-want-me-to-use-the-universe-boss-sticker-chris-gayle-1626179053620" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'ICC%20don't%20want%20me%20to%20use%20'The%20Universe%20Boss'%20sticker%3A%20Chris%20Gayle)' });" style="color:#44444d!important">
# <span itemprop="headline">ICC don't want me to use 'The Universe Boss' sticker: Chris Gayle</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/icc-dont-want-me-to-use-the-universe-boss-sticker-chris-gayle-1626179053620"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T12:24:13.000Z" itemprop="datePublished">05:54 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Talking about using just 'The Boss' sticker instead of 'The Universe Boss' sticker, West Indies' 41-year-old all-rounder Chris Gayle said, "The ICC don't want me to use 'The Universe Boss' sticker so I've shortened it." On being asked if the ICC have copyright over 'Universe Boss', Gayle jokingly added, "I am the boss of cricket, not the ICC."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/icc-dont-want-me-to-use-the-universe-boss-sticker-chris-gayle-1626179053620"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T12:24:13.000Z" itemprop="dateModified">05:54 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/icc-dont-want-me-to-use-the-universe-boss-chris-gayle-on-his-new-bat-stickers/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/uefa-euro-2020-team-of-the-tournament-revealed-1626171857191" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="UEFA Euro 2020 Team of the Tournament revealed" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626170927139_801.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626170927139_801.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/uefa-euro-2020-team-of-the-tournament-revealed-1626171857191" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'UEFA%20Euro%202020%20Team%20of%20the%20Tournament%20revealed)' });" style="color:#44444d!important">
# <span itemprop="headline">UEFA Euro 2020 Team of the Tournament revealed</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/uefa-euro-2020-team-of-the-tournament-revealed-1626171857191"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T10:24:17.000Z" itemprop="datePublished">03:54 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">UEFA Euro 2020 Team of the Tournament has been revealed, featuring five players from winners Italy. Player of the tournament, Italy's Gianluigi Donnarumma has been named goalkeeper. Forward Raheem Sterling, defenders Harry Maguire and Kyle Walker are the three British players in the team. Spanish forward Pedri, who was named Young Player of the Tournament, has also been included.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/uefa-euro-2020-team-of-the-tournament-revealed-1626171857191"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T10:24:17.000Z" itemprop="dateModified">03:54 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://twitter.com/EURO2020/status/1414881871167688707?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Twitter' });" target="_blank">Twitter</a></div>
# </div>
# </div>
# </div>
# <div id="div-gpt-ad-1536748319959-mghtp8dy-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
# <script>
#         googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-mghtp8dy-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-mghtp8dy-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/f1-driver-landos-£40000-watch-stolen-outside-wembley-stadium-after-euro-final-1626184603853" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="F1 driver Lando's £40,000 watch stolen outside Wembley Stadium after Euro final" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626181445241_124.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626181445241_124.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/f1-driver-landos-£40000-watch-stolen-outside-wembley-stadium-after-euro-final-1626184603853" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'F1%20driver%20Lando's%20%C2%A340%2C000%20watch%20stolen%20outside%20Wembley%20Stadium%20after%20Euro%20final)' });" style="color:#44444d!important">
# <span itemprop="headline">F1 driver Lando's £40,000 watch stolen outside Wembley Stadium after Euro final</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/f1-driver-landos-£40000-watch-stolen-outside-wembley-stadium-after-euro-final-1626184603853"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T13:56:43.000Z" itemprop="datePublished">07:26 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">British-Belgian Formula One driver Lando Norris was robbed outside Wembley Stadium in London after attending the Euro 2020 final on Sunday. The 21-year-old had his personalised £40,000 watch stolen while he was going towards his car. McLaren F1 team revealed that a police investigation is underway and, although Lando was left unhurt, he is "still in shock" after the incident.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/f1-driver-landos-£40000-watch-stolen-outside-wembley-stadium-after-euro-final-1626184603853"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-07-13T13:56:43.000Z" itemprop="dateModified">07:26 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.aninews.in/news/sports/football/lando-norris-left-shaken-after-having-watch-stolen-at-wembley20210713153756/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'ANI' });" target="_blank">ANI</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/sourav-gangulys-biopic-confirmed-ranbir-expected-to-play-his-role-1626171103362" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Udit Gupta" itemprop="name"></span>
# </span>
# <span content="Sourav Ganguly's biopic confirmed, Ranbir expected to play his role" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626167871777_870.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626167871777_870.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/sourav-gangulys-biopic-confirmed-ranbir-expected-to-play-his-role-1626171103362" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Sourav%20Ganguly's%20biopic%20confirmed%2C%20Ranbir%20expected%20to%20play%20his%20role)' });" style="color:#44444d!important">
# <span itemprop="headline">Sourav Ganguly's biopic confirmed, Ranbir expected to play his role</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/sourav-gangulys-biopic-confirmed-ranbir-expected-to-play-his-role-1626171103362"><span class="short">short</span></a> by <span class="author">Udit Gupta</span> /
#       <span class="time" content="2021-07-13T10:11:43.000Z" itemprop="datePublished">03:41 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">A film based on the life of BCCI President Sourav Ganguly is in the works. The former Team India captain confirmed the news to News18 and said that it will be made in Hindi. According to reports, Ranbir Kapoor is expected to play the lead role in the upcoming film. It'll reportedly be made on a budget of ₹200-250 crore.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/sourav-gangulys-biopic-confirmed-ranbir-expected-to-play-his-role-1626171103362"><span class="short">short</span></a> by <span class="author">Udit Gupta</span> /
#       <span class="time" content="2021-07-13T10:11:43.000Z" itemprop="dateModified">03:41 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/reports-sourav-ganguly-confirms-the-making-of-biopic-actor-ranbir-kapoor-in-line-to-play-the-role/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/was-excited-to-show-him-what-weve-done-83-maker-on-yashpals-death-1626182618785" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Udit Gupta" itemprop="name"></span>
# </span>
# <span content="Was excited to show him what we've done: '83' maker on Yashpal's death" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626175050293_310.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626175050293_310.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/was-excited-to-show-him-what-weve-done-83-maker-on-yashpals-death-1626182618785" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Was%20excited%20to%20show%20him%20what%20we've%20done%3A%20'83'%20maker%20on%20Yashpal's%20death)' });" style="color:#44444d!important">
# <span itemprop="headline">Was excited to show him what we've done: '83' maker on Yashpal's death</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/was-excited-to-show-him-what-weve-done-83-maker-on-yashpals-death-1626182618785"><span class="short">short</span></a> by <span class="author">Udit Gupta</span> /
#       <span class="time" content="2021-07-13T13:23:38.000Z" itemprop="datePublished">06:53 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Following the demise of former Indian cricketer Yashpal Sharma, '83' director Kabir Khan said, "We received the news in the morning, and it's terrible and shocking." "I was really excited to show him what we've done with his character...it's sad we couldn't show him that part," he added. '83' is based on India's win in the 1983 Cricket World Cup. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/was-excited-to-show-him-what-weve-done-83-maker-on-yashpals-death-1626182618785"><span class="short">short</span></a> by <span class="author">Udit Gupta</span> /
#       <span class="time" content="2021-07-13T13:23:38.000Z" itemprop="dateModified">06:53 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.pinkvilla.com/entertainment/exclusives/exclusive-83-director-kabir-khan-remembers-yashpal-sharma-i-was-excited-show-him-what-we-have-done-810469?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'PINKVILLA' });" target="_blank">PINKVILLA</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/plenty-still-left-in-the-tank-gayle-on-becoming-1st-to-score-14000-t20-runs-1626174104675" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="Plenty still left in the tank: Gayle on becoming 1st to score 14,000 T20 runs" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626170770707_233.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626170770707_233.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/plenty-still-left-in-the-tank-gayle-on-becoming-1st-to-score-14000-t20-runs-1626174104675" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Plenty%20still%20left%20in%20the%20tank%3A%20Gayle%20on%20becoming%201st%20to%20score%2014%2C000%20T20%20runs)' });" style="color:#44444d!important">
# <span itemprop="headline">Plenty still left in the tank: Gayle on becoming 1st to score 14,000 T20 runs</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/plenty-still-left-in-the-tank-gayle-on-becoming-1st-to-score-14000-t20-runs-1626174104675"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T11:01:44.000Z" itemprop="datePublished">04:31 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">After becoming the first batsman to reach 14,000 runs in T20 cricket, West Indies batsman Chris Gayle said he still has "plenty left in the tank". "I may give myself some target, say till up to 15 (thousand runs) now," he added. Gayle smashed 67(38) in their third T20I, helping WI chase down Australia's 141-run total in the 15th over.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/plenty-still-left-in-the-tank-gayle-on-becoming-1st-to-score-14000-t20-runs-1626174104675"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T11:01:44.000Z" itemprop="dateModified">04:31 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.timesnownews.com/amp/sports/cricket/article/plenty-still-left-in-the-tank-chris-gayle-after-14000-run-landmark-in-t20s/784270?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Times%20Now' });" target="_blank">Times Now</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/i-wouldve-said-no-way-sampras-on-3-players-surpassing-his-slam-tally-1626175538948" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anant Kaur" itemprop="name"></span>
# </span>
# <span content="I would've said, no way: Sampras on 3 players surpassing his Slam tally" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626172640061_849.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# ...
# <a href="/prev/en/news/facebook-staff-want-it-to-do-more-against-uk-players-abuse-report-1626178545168"><span class="short">short</span></a> by <span class="author">Aishwarya Awasthi</span> /
#       <span class="time" content="2021-07-13T12:15:45.000Z" itemprop="datePublished">05:45 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Several Facebook employees are "frustrated" that it is not doing enough to stop racist comments on English footballers Bukayo Saka and Marcus Rashford's accounts, journalist Ryan Mac reported. The employees have been flagging comments for over 12 hours now and some are wondering why Facebook wasn't more prepared. Facebook said it removed comments and accounts directing abuse at the players.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/facebook-staff-want-it-to-do-more-against-uk-players-abuse-report-1626178545168"><span class="short">short</span></a> by <span class="author">Aishwarya Awasthi</span> /
#       <span class="time" content="2021-07-13T12:15:45.000Z" itemprop="dateModified">05:45 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.businessinsider.in/tech/news/facebook-employees-are-reportedly-begging-the-company-to-do-more-about-racist-comments-attacking-english-soccer-players-after-the-team-lost-the-euro-cup-final/amp_articleshow/84356915.cms?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Business%20Insider%20India' });" target="_blank">Business Insider India</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/hes-in-your-face-all-the-time-aakash-chopra-on-kohlis-captaincy-1626171174307" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="He's in your face all the time: Aakash Chopra on Kohli's captaincy" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626168879913_630.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626168879913_630.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/hes-in-your-face-all-the-time-aakash-chopra-on-kohlis-captaincy-1626171174307" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'He's%20in%20your%20face%20all%20the%20time%3A%20Aakash%20Chopra%20on%20Kohli's%20captaincy)' });" style="color:#44444d!important">
# <span itemprop="headline">He's in your face all the time: Aakash Chopra on Kohli's captaincy</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/hes-in-your-face-all-the-time-aakash-chopra-on-kohlis-captaincy-1626171174307"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T10:12:54.000Z" itemprop="datePublished">03:42 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Talking about Team India captain Virat Kohli, commentator Aakash Chopra said Kohli knows how to take the crowd along. "He's in your face all the time...We've seen so many captains who're consumed with their captaincy on the ground...but you'll always see Virat jumping and diving around, shouting, appealing...because that's the brand he wants his team to play," Aakash explained. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/hes-in-your-face-all-the-time-aakash-chopra-on-kohlis-captaincy-1626171174307"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T10:12:54.000Z" itemprop="dateModified">03:42 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.sportskeeda.com/amp/cricket/news-aakash-chopra-picks-virat-kohli-s-in-your-face-attitude-one-best-qualities-captain?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Sportskeeda' });" target="_blank">Sportskeeda</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/up-announces-₹6-crore-cash-reward-for-tokyo-olympics-gold-medal-winners-1626169965243" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="UP announces ₹6 crore cash reward for Tokyo Olympics gold medal winners" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626167299827_354.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/07_jul/13_tue/img_1626167299827_354.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/up-announces-₹6-crore-cash-reward-for-tokyo-olympics-gold-medal-winners-1626169965243" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'UP%20announces%20%E2%82%B96%20crore%20cash%20reward%20for%20Tokyo%20Olympics%20gold%20medal%20winners)' });" style="color:#44444d!important">
# <span itemprop="headline">UP announces ₹6 crore cash reward for Tokyo Olympics gold medal winners</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/up-announces-₹6-crore-cash-reward-for-tokyo-olympics-gold-medal-winners-1626169965243"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T09:52:45.000Z" itemprop="datePublished">03:22 pm</span> on <span clas="date">13 Jul 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The Uttar Pradesh government has announced ₹6 crore prize money for all athletes from the state who will win a gold medal in individual events at the Tokyo Olympics. For team events, ₹3 crore each has been announced for the first-place finish. Moreover, the government has announced a ₹10 lakh reward for those who'll participate in Olympics from the state.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/up-announces-₹6-crore-cash-reward-for-tokyo-olympics-gold-medal-winners-1626169965243"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-07-13T09:52:45.000Z" itemprop="dateModified">03:22 pm</span> on <span class="date">13 Jul</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.aninews.in/news/sports/others/tokyo-olympics-up-govt-to-give-rs-6-crore-to-gold-medal-winners-from-state20210713132446/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'ANI' });" target="_blank">ANI</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToFaceBookPage', 'action': 'clicked', 'label': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToTwitterPage', 'action': 'clicked', 'label': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToLinkedinPage', 'action': 'clicked', 'label': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2021</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToTermsAndConditionsAndPP', 'action': 'clicked', 'label': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToSitemap', 'action': 'clicked', 'label': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "rfewfhuw-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls=['https://www.inshorts.com/en/read/sports',
      'https://www.inshorts.com/en/read/world',
      'https://www.inshorts.com/en/read/politics']

def build_dataset(urls):
  news_data=[]
  for u in urls:
    soup=BeautifulSoup(requests.get(u).content)
    category=u.split('/')[-1]                           
    news_article =[{'news_headline': headline.find('span', attrs={"itemprop":"headline"}).string,
                    'news_article': article.find('div', attrs={"itemprop":"articleBody"}).string,
                    'news_category': category}
                   for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                               soup.find_all('div',class_=["news-card-content news-right-box"]))
                   ]
    news_article = news_article[0:20]
    news_data.extend(news_article)
  df=pd.DataFrame(news_data)
  df=df[['news_headline','news_article', 'news_category']]
  return df

# %%
df=build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  F1 driver Lando's £40,000 watch stolen outside...  ...        sports
# 1  I will eat ice-cream with you after the Tokyo ...  ...        sports
# 2  Crawl back under your rock: UK PM to those rac...  ...        sports
# 3  Fan's 2013 tweet predicting Italy's win over E...  ...        sports
# 4  India to send 228 members to Tokyo Games, its ...  ...        sports
#
# [5 rows x 3 columns]

# %%
df=build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  SP's Azam Khan, son recover from COVID-19; shi...  ...      politics
# 56  DNA test ordered to identify body of man who d...  ...      politics
# 57  UP CM Adityanath resumes 'Janata Darshan' prog...  ...      politics
# 58  I don't trust actions of UP Police, BJP govt: ...  ...      politics
# 59  Mekedatu project conspiracy to curb water supp...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/krishna2824/krishna-shree/master/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   I will eat ice-cream with you after the Tokyo ...  ...        sports
# 1   ICC don't want me to use 'The Universe Boss' s...  ...        sports
# 2   Fan's 2013 tweet predicting Italy's win over E...  ...        sports
# 3   F1 driver Lando's £40,000 watch stolen outside...  ...        sports
# 4   Crawl back under your rock: UK PM to those rac...  ...        sports
# 5   India to send 228 members to Tokyo Games, its ...  ...        sports
# 6   Was excited to show him what we've done: '83' ...  ...        sports
# 7   History will never forget you: Jatin Sarna on ...  ...        sports
# 8             Copa America Trophy to be minted as NFT  ...        sports
# 9   Plenty still left in the tank: Gayle on becomi...  ...        sports
# 10  Djokovic 1st player to qualify for 2021 ATP Fi...  ...        sports
# 11  PM Modi condoles demise of 1983 WC-winning bat...  ...        sports
# 12  I would've said, no way: Sampras on 3 players ...  ...        sports
# 13  WI's Stafanie displaces India's Mithali to top...  ...        sports
# 14  WI's Fabian Allen dives to complete rebound af...  ...        sports
# 15  SL tour will be challenging for Hardik Pandya ...  ...        sports
# 16  Facebook staff want it to do more against UK p...  ...        sports
# 17  Muhammad Ali: Mary Kom after PM Modi asks her ...  ...        sports
# 18  MS Dhoni taught Team India a new way of captai...  ...        sports
# 19  Would be frustrating to not be able to partici...  ...        sports
# 20  Most cases of vaccinated people infected by De...  ...         world
# 21  World is witnessing 3rd COVID-19 wave, have to...  ...         world
# 22  Crawl back under your rock: UK PM to those rac...  ...         world
# 23  Iran launches dating app 'Hamdam' to encourage...  ...         world
# 24  Sher Bahadur Deuba replaces KP Oli, becomes Ne...  ...         world
# 25  N Korea forces married women to make cement bl...  ...         world
# 26  2 pet dogs killed in Pakistan for attacking la...  ...         world
# 27  Australia to give 15 lakh doses of AstraZeneca...  ...         world
# 28  Nearly 10 lakh rush to get vaccinated after Fr...  ...         world
# 29  Vietnam to mix doses of Pfizer, AstraZeneca CO...  ...         world
# 30  Chinese drugmakers agree to supply 550 million...  ...         world
# 31  Delta COVID-19 variant cases nearly tripled in...  ...         world
# 32  Man who bought $93,000 Bitcoin in a day gets 3...  ...         world
# 33  Russia says it's against US troops in Central ...  ...         world
# 34  Afghanistan is on brink of humanitarian crisis...  ...         world
# 35  We're holding talks on prisoner exchanges with...  ...         world
# 36  Taliban warns of 'consequences' if Turkey runs...  ...         world
# 37  4 civilians killed, 5 injured in blast in Afgh...  ...         world
# 38  China starts construction of world's 1st comme...  ...         world
# 39  Woman dies, child hurt as roofs of houses coll...  ...         world
# 40  Rajasthan BJP legislator sent to prison in for...  ...      politics
# 41  Smriti Irani, Bhupender Yadav named in politic...  ...      politics
# 42  High time K'taka brings new population policy ...  ...      politics
# 43  Prashant Kishor meets Cong leader Rahul Gandhi...  ...      politics
# 44  At the age of becoming grandfather, Aamir want...  ...      politics
# 45  Rising COVID-19 cases worrying, take action: P...  ...      politics
# 46  BJP MPs to introduce bills on population contr...  ...      politics
# 47  Loot of J&K only motive behind abrogation of A...  ...      politics
# 48  Modi govt is least concerned in protecting peo...  ...      politics
# 49  8 BJP MLAs quit from Bengal Assembly panels ov...  ...      politics
# 50  Kejriwal has done PhD in lying: Anil Vij on wa...  ...      politics
# 51  Rajya Sabha MP to move bill to penalise MPs, M...  ...      politics
# 52  Punjab PCC to get new chief, Amarinder will st...  ...      politics
# 53  Telangana Congress leader Kaushik Reddy expell...  ...      politics
# 54  Centre's inept management of economy caused in...  ...      politics
# 55  SP's Azam Khan, son recover from COVID-19; shi...  ...      politics
# 56  DNA test ordered to identify body of man who d...  ...      politics
# 57  UP CM Adityanath resumes 'Janata Darshan' prog...  ...      politics
# 58  I don't trust actions of UP Police, BJP govt: ...  ...      politics
# 59  Mekedatu project conspiracy to curb water supp...  ...      politics
#
# [60 rows x 3 columns]

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
# function to remove HTML tag
def html_tag(text):
  soup=BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

# %%
# Expand Contraction
# !pip install contractions
import contractions
def con(text):
  expand=contractions.fix(text)
  return expand
con("Y'all can't expand I'd think")
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.52)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.2.0)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# 'you all cannot expand I would think'

# %%
#removal of special charecters
import re
def remove_sp(text):
  pattern= r'[^A-Za-z0-9\s]'
  text= re.sub(pattern,'',text)
  return text

remove_sp("weel this was fun !! what do you think?. #123")
# Out:
# 'weel this was fun  what do you think 123'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer=ToktokTokenizer

# %%
#removal of stopwords
tokenizer = ToktokTokenizer()
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text= ' '.join(filtered_tokens)
  return filtered_text

remove_stopwords("The, and , if are all stop words and even not")
# Out:
# 'The , , stop words even not'

# %%
#1. Lower case
#2. HTMP tags
#3. Contractions
#4. Stopwords
df.news_headline=df.news_headline.apply(lambda x:x.lower())
df.news_article=df.news_article.apply(lambda x:x.lower())


df.news_headline=df.news_headline.apply(html_tag)
df.news_article=df.news_article.apply(html_tag)

df.news_headline=df.news_headline.apply(con)
df.news_article=df.news_article.apply(con)


df.news_headline=df.news_headline.apply(remove_sp)
df.news_article=df.news_article.apply(remove_sp)

df.news_headline=df.news_headline.apply(remove_stopwords)
df.news_article=df.news_article.apply(remove_stopwords)

# %%
# dataset labeling and processing
df['compound'] = df['news_headline'].apply(lambda x: vs.polarity_scores(x)['compound'])
df.head()
# Out:
#                                        news_headline  ... compound
# 0      eat icecream tokyo olympics pm modi pv sindhu  ...   0.0000
# 1  icc not want use universe boss sticker chris g...  ...  -0.0572
# 2  fans 2013 tweet predicting italys win england ...  ...   0.5859
# 3  f1 driver landos 40000 watch stolen outside we...  ...  -0.4939
# 4  crawl back rock uk pm racially abusing footbal...  ...  -0.4588
#
# [5 rows x 4 columns]

# %%
# data finalization 
def predict(comp):
  comp=float(comp)
  if (comp>0):
    return 'positive'
  elif (comp==0):
    return 'neutral'
  else:
    return 'negative'
df['type_pred'] = df['compound'].apply(predict)
df.head()
# Out:
#                                        news_headline  ... type_pred
# 0      eat icecream tokyo olympics pm modi pv sindhu  ...   neutral
# 1  icc not want use universe boss sticker chris g...  ...  negative
# 2  fans 2013 tweet predicting italys win england ...  ...  positive
# 3  f1 driver landos 40000 watch stolen outside we...  ...  negative
# 4  crawl back rock uk pm racially abusing footbal...  ...  negative
#
# [5 rows x 5 columns]
